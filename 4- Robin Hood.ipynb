# %%
points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]

#### 1. Robin Hood is famous for hitting an arrow with another arrow. Find the coordinates of the points where an arrow hits another arrow.

arrows_repeat = []
for i in range(len(points)):
    if points[i] in points[i+1:]:
        arrows_repeat.append(points[i])
print(set(arrows_repeat))

#### 2. Calculate how many arrows have fallen in each quadrant

q1 = []
q2 = []
q3 = []
q4 = []
count = 0

while count < len(points):
    for x, y in points[count: count+1]:
        if x > 0 and y > 0:
            q1.append(points[count])
        elif x < 0 and y > 0:
            q2.append(points[count])
        elif x < 0 and y <0:
            q3.append(points[count])
        elif x >0 and y < 0:
            q4.append(points[count])

    count += 1

print(f"Hay un total de: {q1} primer cuadrante, un total de: {q2} segundo cuadrante, un total de: {q3} tercer cuadrante, un total de: {q4} cuarto cuadrante,")

#### 3. Find the point closest to the center. Calculate its distance to the center

import math

def point(shot):
    for x, y in shot:
        distance = math.sqrt(x ** 2 + y ** 2)
    return distance
    x = shot[0]
    y = shot[1]
    distance = math.sqrt(x ** 2 + y ** 2)
    return distance

distances = []
for i in range(len(points)):
    distances.append(round(point(points[i:i+1]), 2))

for i in points:
    distances.append(round(point(i), 2))
    print(distances)

counter = 0
marksman = []

while counter < len(distances):
    for i in distances:
        if i == min(distances):
            marksman.append(points[counter])
        counter += 1
    for i in distances:
        if i == min(distances):
             marksman.append(points[counter])
        counter += 1

print(f"The closest point(s) to the center is(are): {marksman}")
print(f'the closest point to the center is: {min(distances)}')

#### 4. If the archery target has a radius of 9, calculate the number of arrows that won't hit the target.

radius = 9

print(f'{sum(1 for i in distances if i >= radius)}')
print(sum(1 for i in distances if i > radius))
